# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Base de Dados - Questionário.xlsx - Sheet1.csv',index_col=[0])

# %%
df.head()
# Out:
#      Unnamed: 1                        Unnamed: 2  \
# NaN         NaN                               NaN
# NaN         NaN                               NaN
# NaN         NaN                               NaN
# NaN         NaN                                ID
# NaN         NaN  80260d682079b6090c8285b398c50d97
#
#                             Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# NaN                                NaN        NaN        NaN        NaN
# NaN                                NaN        NaN        NaN        NaN
# NaN                                NaN        NaN        NaN        NaN
# NaN                          ProductID   ClientID   Discount  UnitPrice
# NaN  002552c0663708129c0019cc97552d7d3      14001       0,08      249,2
#
#     Unnamed: 7 Unnamed: 8  Unnamed: 9
# NaN        NaN        NaN         NaN
# NaN        NaN        NaN         NaN
# NaN        NaN        NaN         NaN
# NaN   Quantity    StoreID        Date
# ...

# %%
df = df.iloc[3:,:]

# %%
df.head()
# Out:
#      Unnamed: 1                        Unnamed: 2  \
# NaN         NaN                                ID
# NaN         NaN  80260d682079b6090c8285b398c50d97
# NaN         NaN  3275736da1234f55d52bdf09d86b93bc
# NaN         NaN  f3513eec8f1434b5b7e04ddf3598df40
# NaN         NaN  7180475b60fe6bbbde424d39704a1177
#
#                             Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# NaN                          ProductID   ClientID   Discount  UnitPrice
# NaN  002552c0663708129c0019cc97552d7d3      14001       0,08      249,2
# NaN  001b237c0e9bb435f2e54071129237e93      14001        0,1      162,4
# NaN  00066f42aeeb9f3007548bb9d3f33c381      14001        0,1      194,6
# NaN  001b72dfd63e9833e8c02742adf472e33      14002        0,1      201,6
#
#     Unnamed: 7 Unnamed: 8  Unnamed: 9
# NaN   Quantity    StoreID        Date
# NaN          1          4  12/10/2018
# NaN          1          4   4/25/2019
# NaN          1          4   7/17/2019
# ...

# %%
del(df['Unnamed: 1'])

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index                        Unnamed: 2                         Unnamed: 3  \
# 0    NaN                                ID                          ProductID
# 1    NaN  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 2    NaN  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 3    NaN  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4    NaN  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0   ClientID   Discount  UnitPrice   Quantity    StoreID        Date
# 1      14001       0,08      249,2          1          4  12/10/2018
# 2      14001        0,1      162,4          1          4   4/25/2019
# 3      14001        0,1      194,6          1          4   7/17/2019
# 4      14002        0,1      201,6          2          1   4/10/2018

# %%
columnas = ['index'
            'ID',
            'ProductID',
            'ClientID',
            'Discount',
            'UnitPrice',
            'StoreID','Date']

# %%
df.columns = columnas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17184/2045580752.py in <module>
# ----> 1 df.columns = columnas
#
# ~\miniconda3\envs\rsd\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# ~\miniconda3\envs\rsd\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\miniconda3\envs\rsd\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     767     def _set_axis(self, axis: int, labels: Index) -> None:
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
# ...

# %%
(
# Out:
# <bound method Index.__len__ of Index(['index', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')>
